# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.5612167919924306

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5, k**6 ] for k in x])  # add k**6 to try it
print(X_poly.shape)
#print(X_poly)
# Out:
# (100, 6)

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(x,y)
plt.plot(x, regr_poly.predict(X_poly), 'r')

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [ 14.4277331  -30.69877695  25.57522594  -9.78827668   1.74460714
#   -0.11727638]
# interception:  -0.6670334483058169

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([-0.66703345, -0.01343363,  0.50244979,  0.89817762,  1.18991675,
#         1.39250543,  1.51951719,  1.58332331,  1.5951539 ,  1.5651576 ,
#         1.50245986,  1.41521982,  1.31068579,  1.19524934,  1.07449795,
#         0.95326635,  0.8356863 ,  0.72523517,  0.62478293,  0.53663787,
#         0.46259083,  0.40395814,  0.36162299,  0.33607558,  0.32745174,
#         0.33557022,  0.35996851,  0.39993737,  0.4545538 ,  0.52271279,
#         0.60315752,  0.69450822,  0.79528964,  0.90395709,  1.01892111,
#         1.1385707 ,  1.26129517,  1.38550461,  1.50964889,  1.63223537,
#         1.75184507,  1.86714758,  1.97691445,  2.08003124,  2.17550819,
#         2.26248942,  2.34026077,  2.40825624,  2.46606303,  2.51342516,
#         2.55024571,  2.57658762,  2.59267316,  2.59888191,  2.59574743,
#         2.58395244,  2.56432268,  2.53781928,  2.50552984,  2.46865799,
#         2.42851166,  2.38648985,  2.34406804,  2.30278226,  2.26421163,
#         2.22995961,  2.2016338 ,  2.18082435,  2.16908094,  2.16788842,
#         2.17864098,  2.20261497,  2.24094031,  2.29457044,  2.36425097,
#         2.45048686,  2.55350819,  2.67323458,  2.80923818,  2.96070523,
#         3.12639629,  3.30460499,  3.49311545,  3.68915823,  3.88936496,
#         4.08972144,  4.28551952,  4.47130741,  4.64083868,  4.78701984,
#         4.90185649,  4.97639814,  5.00068153,  4.96367264,  4.85320724,
#         4.65593006,  4.35723257,  3.94118932,  3.39049291,  2.68638759])

# %%
regr_poly.predict(X_poly)
# Out:
# array([-0.66703345, -0.01343363,  0.50244979,  0.89817762,  1.18991675,
#         1.39250543,  1.51951719,  1.58332331,  1.5951539 ,  1.5651576 ,
#         1.50245986,  1.41521982,  1.31068579,  1.19524934,  1.07449795,
#         0.95326635,  0.8356863 ,  0.72523517,  0.62478293,  0.53663787,
#         0.46259083,  0.40395814,  0.36162299,  0.33607558,  0.32745174,
#         0.33557022,  0.35996851,  0.39993737,  0.4545538 ,  0.52271279,
#         0.60315752,  0.69450822,  0.79528964,  0.90395709,  1.01892111,
#         1.1385707 ,  1.26129517,  1.38550461,  1.50964889,  1.63223537,
#         1.75184507,  1.86714758,  1.97691445,  2.08003124,  2.17550819,
#         2.26248942,  2.34026077,  2.40825624,  2.46606303,  2.51342516,
#         2.55024571,  2.57658762,  2.59267316,  2.59888191,  2.59574743,
#         2.58395244,  2.56432268,  2.53781928,  2.50552984,  2.46865799,
#         2.42851166,  2.38648985,  2.34406804,  2.30278226,  2.26421163,
#         2.22995961,  2.2016338 ,  2.18082435,  2.16908094,  2.16788842,
#         2.17864098,  2.20261497,  2.24094031,  2.29457044,  2.36425097,
#         2.45048686,  2.55350819,  2.67323458,  2.80923818,  2.96070523,
#         3.12639629,  3.30460499,  3.49311545,  3.68915823,  3.88936496,
#         4.08972144,  4.28551952,  4.47130741,  4.64083868,  4.78701984,
#         4.90185649,  4.97639814,  5.00068153,  4.96367264,  4.85320724,
#         4.65593006,  4.35723257,  3.94118932,  3.39049291,  2.68638759])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-0.7901986  -1.80622152  1.17800703  0.22137177  3.33052231]
# interception:  1.8271059437407238

# %% [markdown]
# #### Comparison

# %%
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)

plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()

# %% [markdown]
# ## 請計算模型的MSE

# %%
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.5612167919924306

# %%
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.1570800010393647

# %%
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.24726748929585227
